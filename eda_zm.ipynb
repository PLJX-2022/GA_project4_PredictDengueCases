# %% [markdown]
# # Google Search Terms

# %% [markdown]
# This notebook is for Exploratory Data Analysis for search data from Google Trends.
# The following data is collected.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./assets/google_search.csv')

# %%
df.head()
# Out:
#         Week  Dengue fever: (Singapore)  fogging: (Singapore)  \
# 0   1/4/2018                         10                     1
# 1   8/4/2018                          8                     1
# 2  15/4/2018                          5                     0
# 3  22/4/2018                          9                     2
# 4  29/4/2018                         19                     0
#
#    Mosquito: (Singapore)  dengue: (Singapore)  dengue cluster: (Singapore)
# 0                     24                   11                            0
# 1                     23                    6                            1
# 2                     20                    6                            0
# 3                     22                    6                            1
# 4                     19                   15                            1

# %%
fig = plt.figure(figsize=(16,10))
plt.plot(df['Week'], df.iloc[:,1:] )
# Out:
# [<matplotlib.lines.Line2D at 0x7f6ad577c5b0>,
#  <matplotlib.lines.Line2D at 0x7f6ad581aac0>,
#  <matplotlib.lines.Line2D at 0x7f6ad581a910>,
#  <matplotlib.lines.Line2D at 0x7f6ad581a490>,
#  <matplotlib.lines.Line2D at 0x7f6ad581aeb0>]

# %%
# The diff and % changes for Dengue Fever (Diesease)
fig, axes = plt.subplots(nrows=3, figsize=(16,10))
axes[0].plot(df.iloc[:,1])
axes[1].plot(df.iloc[:,1].diff())
axes[2].plot(df.iloc[:,1].pct_change())
